# %% [markdown]
# # ML Pipeline Preparation
# Follow the instructions below to help you create your ML pipeline.
# ### 1. Import libraries and load data from database.
# - Import Python libraries
# - Load dataset from database with [`read_sql_table`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html)
# - Define feature and target variables X and Y

# %%
# import libraries
import re
import matplotlib.pyplot as plt
# %matplotlib inline
import nltk
nltk.download(['punkt', 'wordnet', 'stopwords'])
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import numpy as np
import pandas as pd
import pickle
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.multioutput import MultiOutputClassifier
from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeClassifier
from sqlalchemy import create_engine
from sklearn.metrics import classification_report
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# load data from database
engine = create_engine('sqlite:///disaster_response.db')
df = pd.read_sql('SELECT * FROM disaster_response', engine)
X = df['message']
y = df.drop(['id', 'message', 'original', 'genre'],  axis=1).astype(float)

# %% [markdown]
# ### 2. Write a tokenization function to process your text data

# %%
def tokenize(sentence):
#     sentence = re.sub('[^A-Za-z0-9]+', ' ', sentence)
#     tokens = word_tokenize(sentence.lower().strip())
#     lemmatizer = WordNetLemmatizer()
#     tokens = [lemmatizer.lemmatize(i,'n') for i in tokens]
#     tokens = [lemmatizer.lemmatize(i,'v') for i in tokens]
#     return tokens
    
    tokens = nltk.word_tokenize(sentence)
    lemmatizer = nltk.WordNetLemmatizer()
    
    return [lemmatizer.lemmatize(x).lower().strip() for x in tokens]

# %% [markdown]
# ### 3. Build a machine learning pipeline
# - You'll find the [MultiOutputClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputClassifier.html) helpful for predicting multiple target variables.

# %%
pipeline = Pipeline([
    ('vect', CountVectorizer(tokenizer=tokenize)),
    ('tfidf', TfidfTransformer()),
    ('clf', MultiOutputClassifier(RandomForestClassifier()))
])

# %% [markdown]
# ### 4. Train pipeline
# - Split data into train and test sets
# - Train pipeline

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('vect', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip...oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#            n_jobs=1))])

# %% [markdown]
# ### 5. Test your model
# Report the f1 score, precision and recall on both the training set and the test set. You can use sklearn's `classification_report` function here.

# %%
def classification_results(y_test, y_pred):
    for i, col in enumerate(y_test): 
        print(f'#######################:{col}:#######################')
        print(classification_report(y_test.iloc[:,i], y_pred[:,i]))

# %%
y_pred = pipeline.predict(X_test)

# %%
classification_results(y_test, y_pred)
# Out:
# #######################:related:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.62      0.34      0.44      1508
#         1.0       0.82      0.94      0.87      5001
#         2.0       0.42      0.22      0.29        45
#
# avg / total       0.77      0.79      0.77      6554
#
# #######################:request:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.88      0.98      0.93      5456
#         1.0       0.82      0.36      0.50      1098
#
# avg / total       0.87      0.88      0.86      6554
#
# #######################:offer:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.99      1.00      1.00      6513
#         1.0       0.00      0.00      0.00        41
#
# avg / total       0.99      0.99      0.99      6554
#
# #######################:aid_related:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.71      0.88      0.78      3809
#         1.0       0.75      0.49      0.59      2745
#
# avg / total       0.72      0.72      0.70      6554
#
# #######################:medical_help:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.93      1.00      0.96      6032
#         1.0       0.61      0.08      0.14       522
#
# avg / total       0.90      0.92      0.89      6554
#
# #######################:medical_products:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.95      1.00      0.98      6232
#         1.0       0.62      0.09      0.15       322
#
# avg / total       0.94      0.95      0.94      6554
#
# #######################:search_and_rescue:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.97      1.00      0.99      6365
#         1.0       0.62      0.03      0.05       189
#
# avg / total       0.96      0.97      0.96      6554
#
# #######################:security:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.98      1.00      0.99      6426
#         1.0       0.00      0.00      0.00       128
#
# avg / total       0.96      0.98      0.97      6554
#
# #######################:military:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.97      1.00      0.98      6326
#         1.0       0.48      0.04      0.08       228
#
# avg / total       0.95      0.97      0.95      6554
#
# #######################:child_alone:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00      6554
#
# avg / total       1.00      1.00      1.00      6554
#
# #######################:water:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.94      1.00      0.97      6129
#         1.0       0.86      0.16      0.26       425
#
# avg / total       0.94      0.94      0.92      6554
#
# #######################:food:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.93      0.99      0.96      5841
#         1.0       0.79      0.35      0.49       713
#
# avg / total       0.91      0.92      0.91      6554
#
# #######################:shelter:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.93      1.00      0.96      5977
#         1.0       0.82      0.21      0.34       577
#
# avg / total       0.92      0.93      0.91      6554
#
# #######################:clothing:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.99      1.00      0.99      6448
#         1.0       0.53      0.08      0.15       106
#
# avg / total       0.98      0.98      0.98      6554
#
# #######################:money:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.98      1.00      0.99      6409
#         1.0       0.75      0.02      0.04       145
#
# avg / total       0.97      0.98      0.97      6554
#
# #######################:missing_people:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.99      1.00      0.99      6476
#         1.0       1.00      0.01      0.03        78
#
# avg / total       0.99      0.99      0.98      6554
#
# #######################:refugees:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.97      1.00      0.98      6336
#         1.0       0.57      0.04      0.07       218
#
# avg / total       0.95      0.97      0.95      6554
#
# #######################:death:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.96      1.00      0.98      6253
#         1.0       0.86      0.14      0.25       301
#
# avg / total       0.96      0.96      0.95      6554
#
# #######################:other_aid:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.87      1.00      0.93      5679
#         1.0       0.56      0.03      0.05       875
#
# avg / total       0.83      0.87      0.81      6554
#
# #######################:infrastructure_related:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.93      1.00      0.97      6119
#         1.0       0.29      0.00      0.01       435
#
# avg / total       0.89      0.93      0.90      6554
#
# #######################:transport:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.96      1.00      0.98      6276
#         1.0       0.55      0.04      0.07       278
#
# avg / total       0.94      0.96      0.94      6554
#
# #######################:buildings:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.95      1.00      0.97      6223
#         1.0       0.75      0.05      0.10       331
#
# avg / total       0.94      0.95      0.93      6554
#
# #######################:electricity:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.98      1.00      0.99      6428
#         1.0       1.00      0.04      0.08       126
#
# avg / total       0.98      0.98      0.97      6554
#
# #######################:tools:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.99      1.00      1.00      6515
#         1.0       0.00      0.00      0.00        39
#
# avg / total       0.99      0.99      0.99      6554
#
# #######################:hospitals:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.99      1.00      0.99      6483
#         1.0       0.00      0.00      0.00        71
#
# avg / total       0.98      0.99      0.98      6554
#
# #######################:shops:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00      6526
#         1.0       0.00      0.00      0.00        28
#
# avg / total       0.99      1.00      0.99      6554
#
# #######################:aid_centers:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.99      1.00      0.99      6479
#         1.0       0.00      0.00      0.00        75
#
# avg / total       0.98      0.99      0.98      6554
#
# #######################:other_infrastructure:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.95      1.00      0.98      6252
#         1.0       0.25      0.01      0.01       302
#
# avg / total       0.92      0.95      0.93      6554
#
# #######################:weather_related:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.83      0.96      0.89      4713
#         1.0       0.83      0.51      0.63      1841
#
# avg / total       0.83      0.83      0.82      6554
#
# #######################:floods:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.94      1.00      0.97      6012
#         1.0       0.87      0.24      0.37       542
#
# avg / total       0.93      0.93      0.92      6554
#
# #######################:storm:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.93      0.99      0.96      5934
#         1.0       0.79      0.29      0.43       620
#
# avg / total       0.92      0.93      0.91      6554
#
# #######################:fire:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.99      1.00      0.99      6477
#         1.0       0.57      0.05      0.10        77
#
# avg / total       0.98      0.99      0.98      6554
#
# #######################:earthquake:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.96      0.99      0.98      5921
#         1.0       0.90      0.61      0.73       633
#
# avg / total       0.95      0.96      0.95      6554
#
# #######################:cold:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.98      1.00      0.99      6423
#         1.0       0.57      0.09      0.16       131
#
# avg / total       0.97      0.98      0.97      6554
#
# #######################:other_weather:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.95      1.00      0.97      6221
#         1.0       0.50      0.02      0.03       333
#
# avg / total       0.93      0.95      0.93      6554
#
# #######################:direct_report:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.86      0.98      0.91      5299
#         1.0       0.77      0.31      0.44      1255
#
# avg / total       0.84      0.85      0.82      6554
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### 6. Improve your model
# Use grid search to find better parameters.

# %%
parameters = {'clf__estimator__min_samples_split': [2],
              'clf__estimator__n_estimators': [20, 40]}

cv = GridSearchCV(pipeline, param_grid=parameters, n_jobs =-1)

# %%
cv.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=None, error_score='raise',
#        estimator=Pipeline(memory=None,
#      steps=[('vect', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip...oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#            n_jobs=1))]),
#        fit_params=None, iid=True, n_jobs=-1,
#        param_grid={'clf__estimator__min_samples_split': [2], 'clf__estimator__n_estimators': [20, 40]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %% [markdown]
# ### 7. Test your model
# Show the accuracy, precision, and recall of the tuned model.

# %%
y_pred = cv.predict(X_train)

# %%
classification_results(y_train, y_pred)
# Out:
# #######################:related:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00      4614
#         1.0       1.00      1.00      1.00     14905
#         2.0       1.00      0.99      0.99       143
#
# avg / total       1.00      1.00      1.00     19662
#
# #######################:request:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00     16286
#         1.0       1.00      0.99      1.00      3376
#
# avg / total       1.00      1.00      1.00     19662
#
# #######################:offer:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00     19585
#         1.0       1.00      0.95      0.97        77
#
# avg / total       1.00      1.00      1.00     19662
#
# #######################:aid_related:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00     11547
#         1.0       1.00      1.00      1.00      8115
#
# avg / total       1.00      1.00      1.00     19662
#
# #######################:medical_help:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00     18100
#         1.0       1.00      0.99      0.99      1562
#
# avg / total       1.00      1.00      1.00     19662
#
# #######################:medical_products:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00     18671
#         1.0       1.00      0.98      0.99       991
#
# avg / total       1.00      1.00      1.00     19662
#
# #######################:search_and_rescue:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00     19127
#         1.0       1.00      0.97      0.98       535
#
# avg / total       1.00      1.00      1.00     19662
#
# #######################:security:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00     19319
#         1.0       1.00      0.95      0.97       343
#
# avg / total       1.00      1.00      1.00     19662
#
# #######################:military:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00     19030
#         1.0       1.00      0.98      0.99       632
#
# avg / total       1.00      1.00      1.00     19662
#
# #######################:child_alone:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00     19662
#
# avg / total       1.00      1.00      1.00     19662
#
# #######################:water:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00     18415
#         1.0       1.00      1.00      1.00      1247
#
# avg / total       1.00      1.00      1.00     19662
#
# #######################:food:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00     17452
#         1.0       1.00      1.00      1.00      2210
#
# avg / total       1.00      1.00      1.00     19662
#
# #######################:shelter:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00     17925
#         1.0       1.00      0.99      1.00      1737
#
# avg / total       1.00      1.00      1.00     19662
#
# #######################:clothing:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00     19363
#         1.0       1.00      0.98      0.99       299
#
# avg / total       1.00      1.00      1.00     19662
#
# #######################:money:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00     19203
#         1.0       1.00      0.98      0.99       459
#
# avg / total       1.00      1.00      1.00     19662
#
# #######################:missing_people:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00     19442
#         1.0       1.00      0.97      0.98       220
#
# avg / total       1.00      1.00      1.00     19662
#
# #######################:refugees:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00     19005
#         1.0       1.00      0.98      0.99       657
#
# avg / total       1.00      1.00      1.00     19662
#
# #######################:death:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00     18769
#         1.0       1.00      0.99      1.00       893
#
# avg / total       1.00      1.00      1.00     19662
#
# #######################:other_aid:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00     17091
#         1.0       1.00      0.98      0.99      2571
#
# avg / total       1.00      1.00      1.00     19662
#
# #######################:infrastructure_related:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00     18392
#         1.0       1.00      0.97      0.98      1270
#
# avg / total       1.00      1.00      1.00     19662
#
# #######################:transport:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00     18739
#         1.0       1.00      0.96      0.98       923
#
# avg / total       1.00      1.00      1.00     19662
#
# #######################:buildings:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00     18660
#         1.0       1.00      0.99      1.00      1002
#
# avg / total       1.00      1.00      1.00     19662
#
# #######################:electricity:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00     19256
#         1.0       1.00      0.98      0.99       406
#
# avg / total       1.00      1.00      1.00     19662
#
# #######################:tools:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00     19542
#         1.0       1.00      0.93      0.97       120
#
# avg / total       1.00      1.00      1.00     19662
#
# #######################:hospitals:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00     19450
#         1.0       1.00      0.96      0.98       212
#
# avg / total       1.00      1.00      1.00     19662
#
# #######################:shops:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00     19570
#         1.0       1.00      0.93      0.97        92
#
# avg / total       1.00      1.00      1.00     19662
#
# #######################:aid_centers:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00     19428
#         1.0       1.00      0.98      0.99       234
#
# avg / total       1.00      1.00      1.00     19662
#
# #######################:other_infrastructure:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00     18813
#         1.0       1.00      0.96      0.98       849
#
# avg / total       1.00      1.00      1.00     19662
#
# #######################:weather_related:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00     14206
#         1.0       1.00      1.00      1.00      5456
#
# avg / total       1.00      1.00      1.00     19662
#
# #######################:floods:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00     18049
#         1.0       1.00      0.99      0.99      1613
#
# avg / total       1.00      1.00      1.00     19662
#
# #######################:storm:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00     17839
#         1.0       1.00      1.00      1.00      1823
#
# avg / total       1.00      1.00      1.00     19662
#
# #######################:fire:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00     19457
#         1.0       1.00      0.99      0.99       205
#
# avg / total       1.00      1.00      1.00     19662
#
# #######################:earthquake:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00     17840
#         1.0       1.00      1.00      1.00      1822
#
# avg / total       1.00      1.00      1.00     19662
#
# #######################:cold:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00     19263
#         1.0       1.00      0.99      0.99       399
#
# avg / total       1.00      1.00      1.00     19662
#
# #######################:other_weather:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00     18619
#         1.0       1.00      0.98      0.99      1043
#
# avg / total       1.00      1.00      1.00     19662
#
# #######################:direct_report:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00     15842
#         1.0       1.00      0.99      1.00      3820
#
# avg / total       1.00      1.00      1.00     19662

# %%
y_pred = cv.predict(X_test)

# %%
classification_results(y_test, y_pred)
# Out:
# #######################:related:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.72      0.28      0.40      1508
#         1.0       0.81      0.97      0.88      5001
#         2.0       0.44      0.24      0.31        45
#
# avg / total       0.79      0.80      0.77      6554
#
# #######################:request:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.89      0.99      0.94      5456
#         1.0       0.88      0.42      0.57      1098
#
# avg / total       0.89      0.89      0.88      6554
#
# #######################:offer:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.99      1.00      1.00      6513
#         1.0       0.00      0.00      0.00        41
#
# avg / total       0.99      0.99      0.99      6554
#
# #######################:aid_related:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.74      0.87      0.80      3809
#         1.0       0.77      0.58      0.66      2745
#
# avg / total       0.75      0.75      0.74      6554
#
# #######################:medical_help:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.92      1.00      0.96      6032
#         1.0       0.56      0.05      0.09       522
#
# avg / total       0.89      0.92      0.89      6554
#
# #######################:medical_products:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.95      1.00      0.98      6232
#         1.0       0.71      0.08      0.14       322
#
# avg / total       0.94      0.95      0.93      6554
#
# #######################:search_and_rescue:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.97      1.00      0.99      6365
#         1.0       0.75      0.02      0.03       189
#
# avg / total       0.97      0.97      0.96      6554
#
# #######################:security:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.98      1.00      0.99      6426
#         1.0       0.00      0.00      0.00       128
#
# avg / total       0.96      0.98      0.97      6554
#
# #######################:military:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.97      1.00      0.98      6326
#         1.0       0.57      0.05      0.10       228
#
# avg / total       0.95      0.97      0.95      6554
#
# #######################:child_alone:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00      6554
#
# avg / total       1.00      1.00      1.00      6554
#
# #######################:water:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.95      1.00      0.97      6129
#         1.0       0.92      0.23      0.37       425
#
# avg / total       0.95      0.95      0.93      6554
#
# #######################:food:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.94      0.99      0.96      5841
#         1.0       0.84      0.45      0.58       713
#
# avg / total       0.93      0.93      0.92      6554
#
# #######################:shelter:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.93      1.00      0.96      5977
#         1.0       0.88      0.20      0.32       577
#
# avg / total       0.92      0.93      0.90      6554
#
# #######################:clothing:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.98      1.00      0.99      6448
#         1.0       0.71      0.05      0.09       106
#
# avg / total       0.98      0.98      0.98      6554
#
# #######################:money:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.98      1.00      0.99      6409
#         1.0       0.89      0.06      0.10       145
#
# avg / total       0.98      0.98      0.97      6554
#
# #######################:missing_people:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.99      1.00      0.99      6476
#         1.0       1.00      0.01      0.03        78
#
# avg / total       0.99      0.99      0.98      6554
#
# #######################:refugees:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.97      1.00      0.98      6336
#         1.0       1.00      0.00      0.01       218
#
# avg / total       0.97      0.97      0.95      6554
#
# #######################:death:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.96      1.00      0.98      6253
#         1.0       0.81      0.15      0.25       301
#
# avg / total       0.95      0.96      0.95      6554
#
# #######################:other_aid:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.87      1.00      0.93      5679
#         1.0       0.76      0.01      0.03       875
#
# avg / total       0.85      0.87      0.81      6554
#
# #######################:infrastructure_related:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.93      1.00      0.97      6119
#         1.0       0.00      0.00      0.00       435
#
# avg / total       0.87      0.93      0.90      6554
#
# #######################:transport:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.96      1.00      0.98      6276
#         1.0       0.56      0.06      0.12       278
#
# avg / total       0.94      0.96      0.94      6554
#
# #######################:buildings:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.95      1.00      0.98      6223
#         1.0       0.88      0.06      0.12       331
#
# avg / total       0.95      0.95      0.93      6554
#
# #######################:electricity:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.98      1.00      0.99      6428
#         1.0       0.38      0.02      0.04       126
#
# avg / total       0.97      0.98      0.97      6554
#
# #######################:tools:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.99      1.00      1.00      6515
#         1.0       0.00      0.00      0.00        39
#
# avg / total       0.99      0.99      0.99      6554
#
# #######################:hospitals:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.99      1.00      0.99      6483
#         1.0       0.00      0.00      0.00        71
#
# avg / total       0.98      0.99      0.98      6554
#
# #######################:shops:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00      6526
#         1.0       0.00      0.00      0.00        28
#
# avg / total       0.99      1.00      0.99      6554
#
# #######################:aid_centers:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.99      1.00      0.99      6479
#         1.0       0.00      0.00      0.00        75
#
# avg / total       0.98      0.99      0.98      6554
#
# #######################:other_infrastructure:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.95      1.00      0.98      6252
#         1.0       0.00      0.00      0.00       302
#
# avg / total       0.91      0.95      0.93      6554
#
# #######################:weather_related:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.87      0.96      0.91      4713
#         1.0       0.87      0.62      0.72      1841
#
# avg / total       0.87      0.87      0.86      6554
#
# #######################:floods:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.94      1.00      0.97      6012
#         1.0       0.91      0.36      0.51       542
#
# avg / total       0.94      0.94      0.93      6554
#
# #######################:storm:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.93      0.99      0.96      5934
#         1.0       0.79      0.34      0.47       620
#
# avg / total       0.92      0.93      0.92      6554
#
# #######################:fire:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.99      1.00      0.99      6477
#         1.0       1.00      0.01      0.03        77
#
# avg / total       0.99      0.99      0.98      6554
#
# #######################:earthquake:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.97      0.99      0.98      5921
#         1.0       0.90      0.70      0.79       633
#
# avg / total       0.96      0.96      0.96      6554
#
# #######################:cold:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.98      1.00      0.99      6423
#         1.0       0.64      0.07      0.12       131
#
# avg / total       0.97      0.98      0.97      6554
#
# #######################:other_weather:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.95      1.00      0.97      6221
#         1.0       0.57      0.01      0.02       333
#
# avg / total       0.93      0.95      0.93      6554
#
# #######################:direct_report:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.86      0.98      0.92      5299
#         1.0       0.83      0.35      0.49      1255
#
# avg / total       0.86      0.86      0.84      6554
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### 8. Try improving your model further. Here are a few ideas:
# * try other machine learning algorithms
# * add other features besides the TF-IDF

# %%
pipeline_ada = Pipeline([
        ('vect', CountVectorizer(tokenizer = tokenize)),
        ('tfidf', TfidfTransformer()),
        ('clf', MultiOutputClassifier(AdaBoostClassifier()))
])
parameters_ada = {
    'clf__estimator__learning_rate': [0.5, 1],
    'clf__estimator__n_estimators': [50, 100]
}

cv_ada = GridSearchCV(pipeline_ada, parameters_ada, n_jobs =-1)

# %%
cv_ada.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=None, error_score='raise',
#        estimator=Pipeline(memory=None,
#      steps=[('vect', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip...mator=None,
#           learning_rate=1.0, n_estimators=50, random_state=None),
#            n_jobs=1))]),
#        fit_params=None, iid=True, n_jobs=-1,
#        param_grid={'clf__estimator__learning_rate': [0.5, 1], 'clf__estimator__n_estimators': [50, 100]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
# Best parameters set
cv_ada.best_params_
# Out:
# {'clf__estimator__learning_rate': 0.5, 'clf__estimator__n_estimators': 100}

# %%
y_pred = cv_ada.predict(X_train)

# %%
classification_results(y_train, y_pred)
# Out:
# #######################:related:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.61      0.17      0.26      4614
#         1.0       0.79      0.97      0.87     14905
#         2.0       0.75      0.27      0.40       143
#
# avg / total       0.74      0.77      0.72     19662
#
# #######################:request:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.91      0.98      0.94     16286
#         1.0       0.83      0.54      0.65      3376
#
# avg / total       0.90      0.90      0.89     19662
#
# #######################:offer:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00     19585
#         1.0       1.00      0.13      0.23        77
#
# avg / total       1.00      1.00      1.00     19662
#
# #######################:aid_related:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.76      0.89      0.82     11547
#         1.0       0.80      0.61      0.69      8115
#
# avg / total       0.78      0.78      0.77     19662
#
# #######################:medical_help:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.94      0.99      0.96     18100
#         1.0       0.72      0.21      0.33      1562
#
# avg / total       0.92      0.93      0.91     19662
#
# #######################:medical_products:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.96      1.00      0.98     18671
#         1.0       0.80      0.28      0.42       991
#
# avg / total       0.96      0.96      0.95     19662
#
# #######################:search_and_rescue:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.98      1.00      0.99     19127
#         1.0       0.75      0.18      0.28       535
#
# avg / total       0.97      0.98      0.97     19662
#
# #######################:security:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.98      1.00      0.99     19319
#         1.0       0.85      0.03      0.06       343
#
# avg / total       0.98      0.98      0.98     19662
#
# #######################:military:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.98      1.00      0.99     19030
#         1.0       0.78      0.32      0.45       632
#
# avg / total       0.97      0.98      0.97     19662
#
# #######################:child_alone:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00     19662
#
# avg / total       1.00      1.00      1.00     19662
#
# #######################:water:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.98      0.99      0.98     18415
#         1.0       0.82      0.69      0.75      1247
#
# avg / total       0.97      0.97      0.97     19662
#
# #######################:food:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.96      0.98      0.97     17452
#         1.0       0.83      0.71      0.77      2210
#
# avg / total       0.95      0.95      0.95     19662
#
# #######################:shelter:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.96      0.99      0.97     17925
#         1.0       0.84      0.54      0.65      1737
#
# avg / total       0.95      0.95      0.94     19662
#
# #######################:clothing:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.99      1.00      1.00     19363
#         1.0       0.85      0.45      0.59       299
#
# avg / total       0.99      0.99      0.99     19662
#
# #######################:money:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.98      1.00      0.99     19203
#         1.0       0.74      0.27      0.40       459
#
# avg / total       0.98      0.98      0.98     19662
#
# #######################:missing_people:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.99      1.00      1.00     19442
#         1.0       0.77      0.21      0.33       220
#
# avg / total       0.99      0.99      0.99     19662
#
# #######################:refugees:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.97      1.00      0.99     19005
#         1.0       0.74      0.21      0.32       657
#
# avg / total       0.97      0.97      0.96     19662
#
# #######################:death:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.97      1.00      0.98     18769
#         1.0       0.81      0.44      0.57       893
#
# avg / total       0.97      0.97      0.97     19662
#
# #######################:other_aid:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.88      0.99      0.93     17091
#         1.0       0.66      0.09      0.16      2571
#
# avg / total       0.85      0.88      0.83     19662
#
# #######################:infrastructure_related:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.94      1.00      0.97     18392
#         1.0       0.73      0.07      0.12      1270
#
# avg / total       0.93      0.94      0.91     19662
#
# #######################:transport:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.96      1.00      0.98     18739
#         1.0       0.87      0.22      0.35       923
#
# avg / total       0.96      0.96      0.95     19662
#
# #######################:buildings:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.97      0.99      0.98     18660
#         1.0       0.77      0.36      0.49      1002
#
# avg / total       0.96      0.96      0.96     19662
#
# #######################:electricity:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.99      1.00      0.99     19256
#         1.0       0.77      0.28      0.41       406
#
# avg / total       0.98      0.98      0.98     19662
#
# #######################:tools:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.99      1.00      1.00     19542
#         1.0       0.89      0.07      0.12       120
#
# avg / total       0.99      0.99      0.99     19662
#
# #######################:hospitals:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.99      1.00      0.99     19450
#         1.0       0.61      0.10      0.18       212
#
# avg / total       0.99      0.99      0.99     19662
#
# #######################:shops:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00     19570
#         1.0       0.91      0.11      0.19        92
#
# avg / total       1.00      1.00      0.99     19662
#
# #######################:aid_centers:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.99      1.00      0.99     19428
#         1.0       0.72      0.10      0.17       234
#
# avg / total       0.99      0.99      0.98     19662
#
# #######################:other_infrastructure:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.96      1.00      0.98     18813
#         1.0       0.62      0.05      0.09       849
#
# avg / total       0.94      0.96      0.94     19662
#
# #######################:weather_related:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.87      0.97      0.92     14206
#         1.0       0.88      0.64      0.74      5456
#
# avg / total       0.88      0.88      0.87     19662
#
# #######################:floods:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.96      1.00      0.98     18049
#         1.0       0.91      0.53      0.67      1613
#
# avg / total       0.96      0.96      0.95     19662
#
# #######################:storm:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.95      0.99      0.97     17839
#         1.0       0.80      0.50      0.61      1823
#
# avg / total       0.94      0.94      0.94     19662
#
# #######################:fire:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.99      1.00      1.00     19457
#         1.0       0.76      0.28      0.41       205
#
# avg / total       0.99      0.99      0.99     19662
#
# #######################:earthquake:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.98      0.99      0.99     17840
#         1.0       0.90      0.79      0.84      1822
#
# avg / total       0.97      0.97      0.97     19662
#
# #######################:cold:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.99      1.00      0.99     19263
#         1.0       0.85      0.38      0.52       399
#
# avg / total       0.98      0.99      0.98     19662
#
# #######################:other_weather:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.95      1.00      0.97     18619
#         1.0       0.72      0.12      0.21      1043
#
# avg / total       0.94      0.95      0.93     19662
#
# #######################:direct_report:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.88      0.97      0.92     15842
#         1.0       0.79      0.47      0.59      3820
#
# avg / total       0.87      0.87      0.86     19662

# %%
y_pred = cv_ada.predict(X_test)

# %%
classification_results(y_test, y_pred)
# Out:
# #######################:related:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.58      0.17      0.26      1508
#         1.0       0.79      0.96      0.87      5001
#         2.0       0.33      0.11      0.17        45
#
# avg / total       0.74      0.77      0.72      6554
#
# #######################:request:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.91      0.97      0.94      5456
#         1.0       0.78      0.53      0.63      1098
#
# avg / total       0.89      0.90      0.89      6554
#
# #######################:offer:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.99      1.00      1.00      6513
#         1.0       0.00      0.00      0.00        41
#
# avg / total       0.99      0.99      0.99      6554
#
# #######################:aid_related:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.74      0.88      0.80      3809
#         1.0       0.77      0.58      0.66      2745
#
# avg / total       0.76      0.75      0.75      6554
#
# #######################:medical_help:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.93      0.99      0.96      6032
#         1.0       0.61      0.18      0.27       522
#
# avg / total       0.91      0.93      0.91      6554
#
# #######################:medical_products:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.96      0.99      0.98      6232
#         1.0       0.72      0.27      0.39       322
#
# avg / total       0.95      0.96      0.95      6554
#
# #######################:search_and_rescue:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.97      1.00      0.99      6365
#         1.0       0.66      0.13      0.22       189
#
# avg / total       0.97      0.97      0.96      6554
#
# #######################:security:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.98      1.00      0.99      6426
#         1.0       0.00      0.00      0.00       128
#
# avg / total       0.96      0.98      0.97      6554
#
# #######################:military:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.97      0.99      0.98      6326
#         1.0       0.53      0.19      0.28       228
#
# avg / total       0.96      0.97      0.96      6554
#
# #######################:child_alone:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00      6554
#
# avg / total       1.00      1.00      1.00      6554
#
# #######################:water:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.97      0.98      0.98      6129
#         1.0       0.72      0.62      0.67       425
#
# avg / total       0.96      0.96      0.96      6554
#
# #######################:food:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.96      0.98      0.97      5841
#         1.0       0.78      0.70      0.74       713
#
# avg / total       0.94      0.95      0.94      6554
#
# #######################:shelter:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.95      0.99      0.97      5977
#         1.0       0.82      0.44      0.57       577
#
# avg / total       0.94      0.94      0.93      6554
#
# #######################:clothing:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.99      1.00      0.99      6448
#         1.0       0.75      0.49      0.59       106
#
# avg / total       0.99      0.99      0.99      6554
#
# #######################:money:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.98      1.00      0.99      6409
#         1.0       0.57      0.17      0.26       145
#
# avg / total       0.97      0.98      0.97      6554
#
# #######################:missing_people:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.99      1.00      0.99      6476
#         1.0       0.79      0.14      0.24        78
#
# avg / total       0.99      0.99      0.99      6554
#
# #######################:refugees:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.97      1.00      0.98      6336
#         1.0       0.72      0.16      0.26       218
#
# avg / total       0.96      0.97      0.96      6554
#
# #######################:death:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.97      0.99      0.98      6253
#         1.0       0.74      0.46      0.57       301
#
# avg / total       0.96      0.97      0.96      6554
#
# #######################:other_aid:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.88      0.99      0.93      5679
#         1.0       0.59      0.09      0.16       875
#
# avg / total       0.84      0.87      0.83      6554
#
# #######################:infrastructure_related:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.94      1.00      0.97      6119
#         1.0       0.41      0.03      0.06       435
#
# avg / total       0.90      0.93      0.90      6554
#
# #######################:transport:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.96      1.00      0.98      6276
#         1.0       0.71      0.18      0.29       278
#
# avg / total       0.95      0.96      0.95      6554
#
# #######################:buildings:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.97      0.99      0.98      6223
#         1.0       0.71      0.33      0.45       331
#
# avg / total       0.95      0.96      0.95      6554
#
# #######################:electricity:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.98      1.00      0.99      6428
#         1.0       0.57      0.19      0.29       126
#
# avg / total       0.98      0.98      0.98      6554
#
# #######################:tools:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.99      1.00      1.00      6515
#         1.0       0.00      0.00      0.00        39
#
# avg / total       0.99      0.99      0.99      6554
#
# #######################:hospitals:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.99      1.00      0.99      6483
#         1.0       0.40      0.08      0.14        71
#
# avg / total       0.98      0.99      0.99      6554
#
# #######################:shops:#######################
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00      6526
#         1.0       0.00      0.00      0.00        28
#
# avg / total       0.99      1.00      0.99      6554
#
# #######################:aid_centers:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.99      1.00      0.99      6479
#         1.0       0.33      0.03      0.05        75
#
# avg / total       0.98      0.99      0.98      6554
#
# #######################:other_infrastructure:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.95      1.00      0.98      6252
#         1.0       0.38      0.02      0.04       302
#
# avg / total       0.93      0.95      0.93      6554
#
# #######################:weather_related:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.87      0.97      0.92      4713
#         1.0       0.88      0.63      0.74      1841
#
# avg / total       0.87      0.87      0.87      6554
#
# #######################:floods:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.96      0.99      0.98      6012
#         1.0       0.90      0.53      0.67       542
#
# avg / total       0.95      0.96      0.95      6554
#
# #######################:storm:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.95      0.99      0.97      5934
#         1.0       0.80      0.50      0.62       620
#
# avg / total       0.94      0.94      0.94      6554
#
# #######################:fire:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.99      1.00      0.99      6477
#         1.0       0.58      0.18      0.28        77
#
# avg / total       0.99      0.99      0.99      6554
#
# #######################:earthquake:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.98      0.99      0.98      5921
#         1.0       0.89      0.77      0.83       633
#
# avg / total       0.97      0.97      0.97      6554
#
# #######################:cold:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.99      1.00      0.99      6423
#         1.0       0.68      0.32      0.44       131
#
# avg / total       0.98      0.98      0.98      6554
#
# #######################:other_weather:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.95      0.99      0.97      6221
#         1.0       0.42      0.07      0.12       333
#
# avg / total       0.93      0.95      0.93      6554
#
# #######################:direct_report:#######################
#              precision    recall  f1-score   support
#
#         0.0       0.88      0.96      0.92      5299
#         1.0       0.74      0.44      0.56      1255
#
# avg / total       0.85      0.86      0.85      6554
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### 9. Export your model as a pickle file

# %%
with open('classifier.pkl', 'wb') as file:
    pickle.dump(cv, file)

# %% [markdown]
# ### 10. Use this notebook to complete `train.py`
# Use the template file attached in the Resources folder to write a script that runs the steps above to create a database and export a model based on a new dataset specified by the user.
